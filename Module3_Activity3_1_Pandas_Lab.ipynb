# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeVishal-17/Data_analytics/blob/main/Module3_Activity3_1_Pandas_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 3 – Activity 3.1
# ## Pandas Hands-on Lab (5 Marks)
#
# **Instructions:**
# - Complete all tasks
# - Write code in the given cells
# - Run each cell and show outputs
# - Add comments wherever required
# - Submit the completed notebook (PDF) on LMS
#
# **Name:** Vshal Goyal
# **Roll No.:** BETN1A25107
# **Course:** Data Analytics Using Python (AIL0202)

# %%
# Import required libraries
# Write code to import pandas and numpy
import pandas as pd
import numpy as np

# %% [markdown]
# ## Task 1: Data Creation & Loading (1 Mark)
# Dataset:
#     'Name': ['Aman','Riya','Rahul','Sneha','Karan'],
#     'Department': ['IT','HR','IT','Finance','HR'],
#     'Salary': [50000,60000,55000,65000,52000]

# %%
import pandas as pd
import numpy as np
# Create:
# 1. A Pandas Series from a list of 5 elements
series = pd.Series(['Aman', 'Riya', 'Rahul', 'Sneha', 'Karan'])

# Print Series
print("Pandas Series:\n", series)


# 2. A DataFrame with columns: Name, Department, Salary
data = {
    'Name': ['Aman','Riya','Rahul','Sneha','Karan'],
    'Department': ['IT','HR','IT','Finance','HR'],
    'Salary': [50000,60000,55000,65000,52000]
}

df = pd.DataFrame(data)

# Print DataFrame
print("\nDataFrame:\n", df)


# 3. Write a dataset using (any one): CSV / Excel / JSON
df.to_csv('employee_data.csv', index=False)

print("\nDataset saved as employee_data.csv")
# Out:
# Pandas Series:
#  0     Aman
# 1     Riya
# 2    Rahul
# 3    Sneha
# 4    Karan
# dtype: object
#
# DataFrame:
#      Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
# 3  Sneha    Finance   65000
# 4  Karan         HR   52000
#
# Dataset saved as employee_data.csv

# %% [markdown]
# ## Task 2: Data Exploration (1 Mark)

# %%
# Perform:
# Display first 3 rows
print("First 3 Rows:\n", df.head(3))

# Display dataset information
print("\nDataset Info:")
df.info()

# Display statistical summary
print("\nStatistical Summary:\n", df.describe())
# Out:
# First 3 Rows:
#      Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Department  5 non-null      object
#  2   Salary      5 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
#
# Statistical Summary:
#               Salary
# count      5.000000
# mean   56400.000000
# std     6107.372594
# min    50000.000000
# 25%    52000.000000
# 50%    55000.000000
# 75%    60000.000000
# max    65000.000000

# %% [markdown]
# ## Task 3: Indexing, Filtering & Sorting (1 Mark)

# %%
# Perform:
# 1. Extract first 3 rows using .loc[]
first_3_loc = df.loc[0:2]
print("First 3 rows using .loc[]:\n", first_3_loc)

# 2. Extract Salary column using .iloc[]
salary_col = df.iloc[:, 2]
print("\nSalary column using .iloc[]:\n", salary_col)

# 3. Filter employees with Salary > 55000
filtered_df = df[df['Salary'] > 55000]
print("\nEmployees with Salary > 55000:\n", filtered_df)

# 4. Sort dataset by Salary (descending)
sorted_df = df.sort_values(by='Salary', ascending=False)
print("\nDataset sorted by Salary (descending):\n", sorted_df)
# Out:
# First 3 rows using .loc[]:
#      Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
#
# Salary column using .iloc[]:
#  0    50000
# 1    60000
# 2    55000
# 3    65000
# 4    52000
# Name: Salary, dtype: int64
#
# Employees with Salary > 55000:
#      Name Department  Salary
# 1   Riya         HR   60000
# 3  Sneha    Finance   65000
#
# Dataset sorted by Salary (descending):
#      Name Department  Salary
# 3  Sneha    Finance   65000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
# 4  Karan         HR   52000
# 0   Aman         IT   50000

# %% [markdown]
# ## Task 4: Group-by & Aggregation (1 Mark)

# %%
# Perform:
# 1. Find average salary department-wise
avg_salary = df.groupby('Department')['Salary'].mean()
print("Average Salary (Department-wise):\n", avg_salary)

# 2. Find total and count of employees per department
agg_result = df.groupby('Department')['Salary'].agg(['sum', 'count'])
print("\nTotal and Count of Employees per Department:\n", agg_result)
# Out:
# Average Salary (Department-wise):
#  Department
# Finance    65000.0
# HR         56000.0
# IT         52500.0
# Name: Salary, dtype: float64
#
# Total and Count of Employees per Department:
#                 sum  count
# Department
# Finance      65000      1
# HR          112000      2
# IT          105000      2

# %% [markdown]
# ## Task 5: Data Cleaning & Time-Series (1 Mark)

# %%
# Given:
# df['Joining_Date'] = ['2022-01-10','2021-07-15','2023-03-12','2020-11-05','2022-05-20']
df['Joining_Date'] = ['2022-01-10','2021-07-15','2023-03-12','2020-11-05','2022-05-20']


# Perform:
# 1. Convert Joining_Date to datetime
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'])
print("After converting to datetime:\n", df)

# 2. Extract Year and Month
df['Year'] = df['Joining_Date'].dt.year
df['Month'] = df['Joining_Date'].dt.month
print("\nAfter extracting Year and Month:\n", df)

# 3. Identify duplicate rows
duplicates = df[df.duplicated()]
print("\nDuplicate Rows:\n", duplicates)

# 4. Remove duplicate rows
df_cleaned = df.drop_duplicates()
print("\nData after removing duplicates:\n", df_cleaned)
# Out:
# After converting to datetime:
#      Name Department  Salary Joining_Date
# 0   Aman         IT   50000   2022-01-10
# 1   Riya         HR   60000   2021-07-15
# 2  Rahul         IT   55000   2023-03-12
# 3  Sneha    Finance   65000   2020-11-05
# 4  Karan         HR   52000   2022-05-20
#
# After extracting Year and Month:
#      Name Department  Salary Joining_Date  Year  Month
# 0   Aman         IT   50000   2022-01-10  2022      1
# 1   Riya         HR   60000   2021-07-15  2021      7
# 2  Rahul         IT   55000   2023-03-12  2023      3
# 3  Sneha    Finance   65000   2020-11-05  2020     11
# 4  Karan         HR   52000   2022-05-20  2022      5
#
# Duplicate Rows:
#  Empty DataFrame
# Columns: [Name, Department, Salary, Joining_Date, Year, Month]
# Index: []
#
# Data after removing duplicates:
#      Name Department  Salary Joining_Date  Year  Month
# 0   Aman         IT   50000   2022-01-10  2022      1
# 1   Riya         HR   60000   2021-07-15  2021      7
# 2  Rahul         IT   55000   2023-03-12  2023      3
# 3  Sneha    Finance   65000   2020-11-05  2020     11
# 4  Karan         HR   52000   2022-05-20  2022      5
